# %%
def find_word(N,test_str):  
    count = 0
    res = "" 
    for ele in test_str: 
        if ele == '\t': 
            count = count + 1
            if count == N: 
                break
            res = "" 
        else : 
            res = res + ele 

    return(res)

def Create_Bed(string,minus):
    auto={"chr1","chr2","chr3","chr4","chr5","chr6","chr7","chr8","chr9","chr10","chr11","chr12","chr13","chr14","chr15","chr16","chr17","chr18","chr19","chr20","chr21","chr22"}
    ans=''
    for line in string.split('\n'):
        if find_word(2,line) in auto:
            
            ans=ans+" " +find_word(2,line)+" " + str(int(find_word(3,line))-minus)+ " " + str(int(find_word(4,line))+ minus) + "\n"

            #print(ans,end="\n")
    return ans

# %%
with open ("C:\\Users\\aravi\\Desktop\\cpgIslandExt.txt") as file:
    string=file.read()
    cpg_island=Create_Bed(string,0)
    shores=Create_Bed(string,2000)
    shelves=Create_Bed(string,4000)
    file.close()
with open ("C:\\Users\\aravi\\Desktop\\cpg_island.bed","w") as f:
    f.write(cpg_island)
    f.close()
with open ("C:\\Users\\aravi\\Desktop\\shores.bed","w") as f:
    f.write(shores)
    f.close()
with open ("C:\\Users\\aravi\\Desktop\\shelves.bed","w") as f:
    f.write(shelves)
    f.close()
print(final)
# Out:
#  chr1 26735 31810
#  chr1 133124 137563
#  chr1 325790 330229
#  chr1 435151 440164
#  chr1 447273 452544
#  chr1 531219 536114
#  chr1 542738 548649
#  chr1 711984 716547
#  chr1 760416 765445
#  chr1 786863 791211
#  chr1 799975 804338
#  chr1 803198 807628
#  chr1 837694 842619
#  chr1 842299 847883
#  chr1 852765 856973
#  chr1 856970 863632
#  chr1 867332 873872
#  chr1 873730 880363
#  chr1 884356 888602
#  chr1 892313 904654
#  chr1 904296 908538
#  chr1 910869 915153
#  chr1 917726 921927
#  chr1 931387 939410
#  chr1 946670 950894
#  chr1 947329 951851
#  chr1 952768 958343
#  chr1 961795 966507
#  chr1 965966 972238
#  chr1 973496 982305
#  chr1 979068 983400
#  chr1 980152 984511
#  chr1 981174 985612
#  chr1 982206 986429
#  chr1 988274 992694
#  chr1 992436 997303
#  chr1 997678 1001911
#  chr1 1000663 1007318
#  chr1 1009509 1015402
#  chr1 1014863 1019439
#  chr1 1016099 1020390
#  chr1 1017818 1022026
#  chr1 1021143 1025347
#  chr1 1022075 1026614
# ...
